# %% [markdown]
# ## Matplotlib Tutorial 2 - format strings in plot function

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [50, 51, 52, 48, 47, 49, 46]

# %%
# plt.plot(x, y, "g+" )
# plt.plot(x, y, "ro--" )
# plt.plot(x, y, "o--r" ) # any order
# plt.plot(x, y, "D-.b" )
# plt.plot(x, y, color="blue", marker="*", linestyle="dotted")
# plt.plot(x, y, color="#885522", marker="o", linestyle="")
# plt.plot(x, y, color="#885522", marker="o", linestyle="-", linewidth=10, markersize=30)
plt.plot(x, y, color="green", alpha=0.2)
