# %% [markdown]
# ## Matplotlib Tutorial 6 - Pie Chart

# %%
import matplotlib.pyplot as plt

exp_vals = [1400, 600, 300, 410, 250]
exp_labels = ["Home Rent", "Food", "Phone/Internet Bill", "Car ", "Other Utilities"]

# plt.pie(exp_vals, labels=exp_labels, radius=1.5)
# plt.pie(exp_vals, labels=exp_labels, autopct="%0.0f%%") # no dec
# plt.pie(exp_vals, labels=exp_labels, autopct="%0.2f%%") # two dec
# plt.pie(exp_vals, labels=exp_labels, autopct="%0.2f%%", shadow=True)
# plt.pie(exp_vals, labels=exp_labels, autopct="%0.2f%%", explode=[0, 0.1, 0.2, 0, 0]); # choose what to pull out
plt.pie(exp_vals, labels=exp_labels, startangle=45)  # rotate
# plt.axis("equal") # perfect circle. Still needed?
# plt.show()
